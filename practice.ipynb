# %%
from os import name

n = int(input("enter a number"))
sum = 0
for i in range(1, n+1):
    sum = sum+i
print(sum)
# Out:
# 15

# %%
n = int(input("enter a number"))
sum = 0
while n > 0:
    sum = sum + n
    n = n - 1
print(sum)
# Out:
# 15

# %%
n = int(input("enter a number"))
fact = 1
for i in range(1, n+1):
    fact = fact*i
print(fact)
# Out:
# 120

# %%
n = int(input("enter a number"))
fact = 1
while n>0:
    fact = fact*n
    n = n - 1
print(fact)
# Out:
# 120

# %%
n = int(input("enter a number"))
for i in range(0 , n, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
n = int(input("enter a number"))
i = 0
while i<n:
    print(i)
    i=i+2
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
n = int(input("enter a number"))
for i in range(1, n+1):
    for j in range(i):
        print("*", end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
n = input("enter a number")
rev = ""
for i in range(len(n) -1,-1,-1):
    rev = rev+n[i]
print(rev)
# Out:
# vytfyh

# %%
n = input("enter a number")
rev = ""
i = len(n)-1
while i>=0:
    rev = rev+n[i]
    i=i-1
print(rev)
# Out:
# ojij

# %%
from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def sound(self):
        print("bhsuw dshbcjhb")
class dog(Animal):
    def sound(self):
        print("I am dog.")
d1 = dog()
d1.sound()
# Out:
# I am dog.

# %%
class Charger:
    def charge(self):
        print("Charging...")

class Mobile:
    def __init__(self, charger):
        self.charger = charger

    def start(self):
        self.charger.charge()
c = Charger()
m = Mobile(c)
m.start()
# Out:
# Charging...
# Charging...

# %%
class computer:
    def __init__(self,brand):
        self.brand = brand
        self.cpu = cpu()
    def show(self):
        print(f"brand is {self.brand}")
        self.cpu.display()

    def __del__(self):
        print("computer is deleted")
class cpu:
    def __init__(self):
        self.cores = 4
        self.speed = "3.4 ghz"
    def display(self):
        print(f"cpu {self.cores} cores at {self.speed}")
    def __del__(self):
        print("cpu is deleted")
c = computer("lenovo")
c.show()
del c
# Out:
# brand is lenovo
# cpu 4 cores at 3.4 ghz
# computer is deleted
# cpu is deleted

# %%
class os:
    def __init__(self):
        self.status = True
        print("os is ready")
    def getos(self):
        print("os is installing")
class mobile:
    def __init__(self,name):
        self.mname = name
        self.os = os()
        print("mobile is ready")
        print("with a os")
m1 = mobile("samsung")
print(m1.mname)
m1.os.getos()
# del m1
# print(m1.mname)
# Out:
# os is ready
# mobile is ready
# with a os
# samsung
# os is installing

# %%
class book:
    def __init__(self, title):
        self.title = title
class library:
    def __init__(self,books):
        self.books = books
    def show_books(self):
        for book in self.books:
            print(book.title)
book1 = book("1234")
book2 = book("bvyv gefwtv")

library = library([book1,book2])
library.show_books()
del library
print(book1.title)
print(book2.title)
# Out:
# 1234
# bvyv gefwtv
# 1234
# bvyv gefwtv

# %%
l = [3,7,9,65,34,86]
largest = max(l)
print(largest)
# Out:
# 86

# %%
thickness = int(input())
c = 'H'

for i in range(thickness):
    print((c*i).rjust(thickness-1)+c+(c*i).ljust(thickness-1))
# Out:
#     H
#    HHH
#   HHHHH
#  HHHHHHH
# HHHHHHHHH

# %%
color1 = {"red","blue","green"}
color2 = {"blue","green", "yellow"}
print(color1^color2)
# Out:
# {'red', 'yellow'}

# %%
class Dog:
    def __init__(self):
        self.name = name
        self.age = 2
        self.weight = 10
        self.breed = "bidhi nayi"
    def bark(self):
        print("Dog is barking")
d1 = Dog
d1.name = "rony"
d1.age = 2
d1.weight = 10
print(d1.name)
print(d1.age)
print(d1.weight)
del d1.weight
print(d1.weight)
d1.name = "papu"
print(d1.name)
# Out:
# rony
# 2
# 10
# papu

# %%
class Radio:
    def Turnon(self,x):
        if x == 1:
            print("Radio will on")
        else:
            print("Radio will off")
class car:
    def __init__(self,min,max):
        self.min = min
        self.max = max
        self.R = Radio()
c1 = car(45,65)
print(c1.min)
print(c1.max)
c1.R.Turnon(1)
# Out:
# 45
# 65
# Radio will on

# %%
class os:
    def __init__(self):
        self.status = True
    def getos(self):
        print("os is ready")
class mobile:
    def __init__(self,name):
        self.name = name
        self.O = os()
        print("mobile is ready")
        print("with a os")
m1 =mobile("samsung")
print(m1.name)
print(m1.O.status)
m1.O.getos()
# Out:
# mobile is ready
# with a os
# samsung
# True
# os is ready

# %%
class charger :
    def __init__(self,name) :
        self.cname=name
    def getcharger(self) :
        print("Charger is working")
class mobile :
    def __init__(self,name) :
        self.mname=name
        self.c = ""
    def hasmobile(self,p) :
        self.c=p
m1 = mobile("IQ")
c = charger("C pin")
m1.hasmobile(c)
print(m1.mname)
print(m1.c.cname)
m1.c.getcharger()
del m1
print(c.cname)
c.getcharger()
# Out:
# IQ
# C pin
# Charger is working
# C pin
# Charger is working
