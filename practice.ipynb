# %%
n = int(input("enter a number"))
sum = 0
for i in range(1, n+1):
    sum = sum+i
print(sum)
# Out:
# 15

# %%
n = int(input("enter a number"))
sum = 0
while n > 0:
    sum = sum + n
    n = n - 1
print(sum)
# Out:
# 15

# %%
n = int(input("enter a number"))
fact = 1
for i in range(1, n+1):
    fact = fact*i
print(fact)
# Out:
# 120

# %%
n = int(input("enter a number"))
fact = 1
while n>0:
    fact = fact*n
    n = n - 1
print(fact)
# Out:
# 120

# %%
n = int(input("enter a number"))
for i in range(0 , n, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
n = int(input("enter a number"))
i = 0
while i<n:
    print(i)
    i=i+2
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
n = int(input("enter a number"))
for i in range(1, n+1):
    for j in range(i):
        print("*", end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
