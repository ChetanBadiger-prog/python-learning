# %%
from copy import deepcopy


class student:
    def __init__(self,name):
        self.name = name
    def display(self):
        print("name :",self.name)
s1 = student("chethan")
s1.display()
# Out:
# name : chethan

# %%
class student:
    college_name = "abc college"

    @classmethod
    def display(cls):
        print("college name :", cls.college_name)
s1 = student()
s1.display()
# Out:
# college name : abc college

# %%
class student:
    @staticmethod
    def display():
        print("hello")
s1 = student()
s1.display()
# Out:
# hello

# %%
class student:
    def __init__(self,name,age,gender):
        self.name = name
        self.age = age
        self.gender = gender
s1 = student("chethan",22,"male")
s2 = student("abc",33,"female")
print(s1.name)
print(s2.age)
# Out:
# chethan
# 33

# %%
def greet():
    print("hello")
greet()
# Out:
# hello

# %%
def add(a,b):
    return a+b
a1 = add(3,4)
print(a1)
# Out:
# 7

# %%
def get_number():
    return 10
a = get_number()
print(a)
# Out:
# 10

# %%
def greet(name):
    print("hello",name)
greet("chethan")
# Out:
# hello chethan

# %%
class student:
    college="gec college, challakere"
    @classmethod
    def display(cls):
        print("college name :",cls.college)
s1=student()
s1.display()
# Out:
# college name : gec college, challakere

# %%
def outer(fun):
    a='s'
    def inner(a,b):
        p=a*b
        def inner1(a,b):
            return a-b
    return inner

# outer()
@outer
def add(a,b):
    return a+b

print(add(3,4))
# Out:
# None

# %%
l = []
i = 0
while True:
    num = int(input("enter a number"))
    l.append(num)
    i = i*3
    print("do you want to continue ")
    print("press 1 for yes and pree 2 for no")
    choice = int(input("enter your choice"))
    if choice ==  1:
        continue
    else:
        break
print()
# Out:
# [4, 6]

# %%
l = ["10","20",["90","hello","hi"],"90"]
print(l)
print(l[2])
print(l[2][1])
# Out:
# ['10', '20', ['90', 'hello', 'hi'], '90']
# ['90', 'hello', 'hi']
# hello

# %%
l = ["10","20","30","40","90"]
l1 = l
print(l)
print(l1)
print(l[2])
l[2]=300
print(l)
print(l1)
# Out:
# ['10', '20', '30', '40', '90']
# ['10', '20', '30', '40', '90']
# 30
# ['10', '20', 300, '40', '90']
# ['10', '20', 300, '40', '90']

# %%
l = [10,20,33,40,50]
l1 = l.copy()
print(l)
print(l)
del l[2]
print(l)
print(l1)
# Out:
# [10, 20, 33, 40, 50]
# [10, 20, 33, 40, 50]
# [10, 20, 40, 50]
# [10, 20, 33, 40, 50]

# %%
lst = [0,1,2,3,4,5,6,]
reversed_list=[]
for i in range(len(lst)-1,-1,-1):
    reversed_list.append(lst[i])
print(reversed_list)
# Out:
# [6, 5, 4, 3, 2, 1, 0]

# %%
str = input("enter a string :")
rev = ""
for i in range(len(str)):
    rev = str[i]+rev
print(rev)
if str==rev:
    print("is palindrome")
else:
    print("is not palindrome")
# Out:
# olleh
# is not palindrome

# %%
str = "good morning"
rev = ""
str1 = str.split()
for i in str1:
    rev = i+" "+rev
print(rev)
# Out:
# morning good

# %%
str = "hello"
rev = ""
for i in range(len(str)):
    rev = str[i]+rev
print(rev)
# Out:
# olleh
